# %%
# Importing the libraries
import numpy as np # for array operations
import pandas as pd # for working with DataFrames
# import requests, io # for HTTP requests and I/O commands
import matplotlib.pyplot as plt # for data visualization
#%matplotlib inline

# scikit-learn modules
from sklearn.model_selection import train_test_split # for splitting the data
from sklearn.metrics import mean_squared_error, classification_report, accuracy_score # for calculating the cost function
from sklearn.tree import DecisionTreeRegressor # f

# %%
#Cargo el archivo parquet
df = pd.read_parquet(r'dataset\diabetes_ok.parquet')

# %%
df.sample(6)
# Out:
#       Age  Gender  BMI  Chol    TG   HDL   LDL    Cr   BUN  Diabetes
# 57     44       0   21  4.90  2.80  2.00  1.80  64.0  6.80         0
# 1066   45       0   26  3.88  2.12  1.04  2.11  71.3  4.40         0
# 3902   64       0   24  6.32  1.09  1.24  4.27  70.4  4.55         1
# 686    73       1   22  3.40  1.50  1.20  2.90  50.0  3.10         1
# 2799   35       0   20  4.38  0.90  1.62  2.12  61.0  2.78         0
# 874    30       0   19  2.21  0.66  0.80  1.25  73.0  3.64         0

# %%
df.shape
# Out:
# (5131, 10)

# %%
df1 = df.copy()

# %% [markdown]
# ### Separating the features and the target variable

# %%
x = df1.drop(['Diabetes'], axis=1) #Features
y = df1['Diabetes'] #target

# %% [markdown]
# ### Spliting the data into train set and a test set

# %%
# Splitting the dataset into training and testing set (80/20)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 28)

# %% [markdown]
# ### Fitting the model to the training dataset

# %%
# Initializing the Decision Tree Regression model
model = DecisionTreeRegressor(criterion='poisson',random_state = 0)

# Fitting the Decision Tree Regression model to the data
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', random_state=0)

# %% [markdown]
# ### Calculating the loss after training

# %%
# Predicting the target values of the test set
y_pred = model.predict(x_test)

# RMSE (Root Mean Square Error)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("\nRMSE: ", rmse)
# Out:
# RMSE:  0.434

# %%
accuracy = accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 accuracy = accuracy_score(y_test, y_pred)
#
# File d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\metrics\_classification.py:213, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     147 """Accuracy classification score.
#     148
#     149 In multilabel classification, this function computes subset accuracy:
#    (...)
#     209 0.5
#     210 """
#     212 # Compute accuracy for each possible representation
# --> 213 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     214 check_consistent_length(y_true, y_pred, sample_weight)
#     215 if y_type.startswith("multilabel"):
#
# File d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(classification_report(y_test, y_pred))
#
# File d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2604, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2469 @validate_params(
#    2470     {
#    2471         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2495     zero_division="warn",
#    2496 ):
#    2497     """Build a text report showing the main classification metrics.
#    2498
#    2499     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2601     <BLANKLINE>
#    2602     """
# -> 2604     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2606     if labels is None:
#    2607         labels = unique_labels(y_true, y_pred)
#
# File d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\metrics\_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
# ### Exporto el modelo

# %%
# Model saved
import joblib as jb

# %%
jb.dump(model, 'blood_model.pkl')
# Out:
# ['blood_model.pkl']

# %%
#load model
jb.load('blood_model.pkl')
# Out:
# DecisionTreeRegressor(criterion='poisson', random_state=0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5131 entries, 0 to 5130
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       5131 non-null   int64
#  1   Gender    5131 non-null   int64
#  2   BMI       5131 non-null   int64
#  3   Chol      5131 non-null   float64
#  4   TG        5131 non-null   float64
#  5   HDL       5131 non-null   float64
#  6   LDL       5131 non-null   float64
#  7   Cr        5131 non-null   float64
#  8   BUN       5131 non-null   float64
#  9   Diabetes  5131 non-null   int64
# dtypes: float64(6), int64(4)
# memory usage: 401.0 KB

# %% [markdown]
# ### Make a prediction

# %%
Age= 20  
Gender= 0
BMI= 20
Chol= 5
TG= 5
HDL= 3
LDL= 3
Cr= 70
BUN= 5

# %%
test_result =[
    Age,
    Gender,
    BMI,
    Chol,
    TG,
    HDL,
    LDL,
    Cr,
    BUN
]

# %%
#Prediction
#W = np.array(v_list)
w_pred = model.predict([test_result])
print([w_pred])
print(int(w_pred[0]))
# Out:
# [array([0.33333333])]
# 0
# d:\0_Respaldo\0_Proyectos_2024\Diabetes alert\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
